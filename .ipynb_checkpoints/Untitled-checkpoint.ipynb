# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
img_path = '/home/pytholic/Desktop/Projects/uav_mapping/open3d_midas/MiDaS/input/1.png'

# %%
img = cv2.imread(img_path)
img_meters = img * 0.001

# %%
print(img_meters)

# %%
x, y = 227, 220
print(img_meters[x][y])

# %%
cv2.imshow('depth map', img)
key = cv2.waitKey(0)
if key == 27:
    cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x560e35dd6d30) is not the object's thread (0x560e3575aae0).
# Cannot move to target thread (0x560e35dd6d30)
#
# QObject::moveToThread: Current thread (0x560e35dd6d30) is not the object's thread (0x560e3575aae0).
# Cannot move to target thread (0x560e35dd6d30)
#
# QObject::moveToThread: Current thread (0x560e35dd6d30) is not the object's thread (0x560e3575aae0).
# Cannot move to target thread (0x560e35dd6d30)
#
# QObject::moveToThread: Current thread (0x560e35dd6d30) is not the object's thread (0x560e3575aae0).
# Cannot move to target thread (0x560e35dd6d30)
#
# QObject::moveToThread: Current thread (0x560e35dd6d30) is not the object's thread (0x560e3575aae0).
# Cannot move to target thread (0x560e35dd6d30)
#
# QObject::moveToThread: Current thread (0x560e35dd6d30) is not the object's thread (0x560e3575aae0).
# Cannot move to target thread (0x560e35dd6d30)
#
# ...
